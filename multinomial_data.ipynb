# %%
# 1.csv Jan 1, 2013- April 5, 2022; 
# 2.csv Jan 1, 2003 – December 31, 2012 
# 3.csv Jan 1, 1993 - December 31, 2002

# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime
import pickle

# %%
import sqlite3
conn = sqlite3.connect('database.db')
cur = conn.cursor()

# %%
# use lambda fucntions for column-wise operations on every record
shortened_date = lambda d : datetime.strptime(d[:10], '%Y-%m-%d')
set_month_year = lambda d : str(d.year)+str(d.month)
set_year = lambda d : d.year
set_month = lambda d : d.month

# %%
ncd_cols = ['DATE', 'REPORT_TYPE', 
            'DailyAverageDryBulbTemperature', 
            'DailyAverageStationPressure',
            'DailyAverageWindSpeed', 
            'DailyCoolingDegreeDays', 'DailyDepartureFromNormalAverageTemperature', 
            'DailyHeatingDegreeDays',
            'DailyMaximumDryBulbTemperature', 'DailyMinimumDryBulbTemperature', 
            'DailyPeakWindDirection', 'DailyPeakWindSpeed', 
            'DailyPrecipitation', 
            'DailySustainedWindDirection', 'DailySustainedWindSpeed',
            'DailyWeather']

# %%
df1 = pd.read_csv('datasets/nenana_climate/1.csv', usecols = ncd_cols) 
df2 = pd.read_csv('datasets/nenana_climate/2.csv', usecols = ncd_cols) 
df3 = pd.read_csv('datasets/nenana_climate/3.csv', usecols = ncd_cols)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (21,27,28,29,30,31,32,33,37,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (21,27,28,29,30,31,33,34,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# datetime objects for easily creating other numerical fields
df1['DATE'] = df1['DATE'].apply(shortened_date)
df2['DATE'] = df2['DATE'].apply(shortened_date)
df3['DATE'] = df3['DATE'].apply(shortened_date)
# SOD = sum of day, delete all other records 
df1 = df1[df1['REPORT_TYPE']=='SOD  '].set_index('DATE').drop('REPORT_TYPE',1) 
df2 = df2[df2['REPORT_TYPE']=='SOD  '].set_index('DATE').drop('REPORT_TYPE',1) 
df3 = df3[df3['REPORT_TYPE']=='SOD  '].set_index('DATE').drop('REPORT_TYPE',1)

# %%
nenana_climate = pd.concat([df1,df2,df3]).reset_index()
nenana_climate['year'] = nenana_climate['DATE'].apply(set_year)
nenana_climate['month'] = nenana_climate['DATE'].apply(set_month)

# %%
years_index = sorted([y for y in nenana_climate['year'].unique()])
months_index = sorted([m for m in nenana_climate['month'].unique()])

# %%
# Problem: these weather types are individual entries on random days 
# Solution: compact entries into monthly lists 
t= dict()
for y in years_index:
    t[y] = {}
    for m in months_index:
        t[y][m] =[]
        for v in nenana_climate[ (nenana_climate['year']==y) & (nenana_climate['month']==m) ].DailyWeather.values:
            if type(v)== str: 
                t[y][m]+= [y for y in v.split() ]

# %%
# to join with class labels 
weather_types = pd.DataFrame.from_dict(t);
events = pd.read_sql("""
    SELECT * 
    from nib;
    """, con=conn)

# %%
labels = list( events[events['Year']>=1996].month.values)
labels.append('?') # missing label most recent years 2021, 2022 
labels.append('?')
weather_types = weather_types.transpose()
weather_types['class_month'] = labels

# %%
# final data frame 
weather_types
# Out:
#                                                       1  \
# 1996       [SN, SN, FG, FG, FG, FG, FG, FG, SN, SN, SN]
# 1997                               [BR, BR, SN, SN, BR]
# 1998  [SN, SN, SN, BR, FG, BR, HZ, SN, BR, HZ, HZ, S...
# 1999  [SN, SN, BR, HZ, BR, SN, BR, SN, BR, SN, BR, S...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [HZ, SN, BR, SN, BR, SN, BR, HZ, BR, HZ, BR, H...
# 2005  [SN, UP, SN, BR, UP, SN, BR, UP, SN, FZFG, BR,...
# 2006  [SN, SN, SN, BR, SN, BR, SN, HZ, SN, FZFG, BR,...
# 2007  [SN, BR, HZ, RA, HZ, RA, SN, HZ, RA, SN, HZ, R...
# 2008  [RA, SN, SN, RA, SN, RA, SN, UP, SN, HZ, RA, S...
# 2009  [SN, BR, HZ, BR, HZ, SN, BR, HZ, SN, BR, HZ, R...
# 2010  [SN, SN, RA, RA, BR, RA, RA, BR, RA, BR, RA, B...
# 2011  [RA, SN, BR, RA, SN, UP, RA, SN, BR, UP, RA, S...
# 2012  [BR, HZ, RA, SN, BR, HZ, RA, BR, HZ, RA, SN, H...
# 2013  [RA, BR, RA, RA, RA, RA, RA, SN, BR, RA, SN, H...
# 2014  [RA, SN, RA, SN, SN, RA, RA, RA, SN, HZ, FZFG,...
# 2015  [SN, BR, SN, SN, RA, RA, BR, RA, UP, RA, RA, S...
# 2016  [BR, HZ, RA, RA, RA, SN, FZRA, SN, BR, HZ, RA,...
# 2017  [SN, BR, SN, BR, SN, BR, UP, BR, SN, SN, BR, S...
# 2018  [BR, BR, UP, FZRA, SN, BR, RA, FZRA, SN, FZFG,...
# 2019  [RA, SN, FZFG, BR, UP, FG, BR, UP, HZ, HZ, BR,...
# 2020  [SN, BR, UP, HZ, SN, HZ, HZ, SN, HZ, BR, HZ, B...
# 2021   [HZ, SN, BR, UP, UP, BR, HZ, HZ, HZ, SN, SN, HZ]
# 2022                                       [SN, UP, HZ]
#
#                                                       2  \
# 1996   [FG, FG, FG, FG, SN, FG, SN, SN, SN, SN, SN, SN]
# 1997                               [BR, SN, BR, BR, SN]
# 1998               [SN, BR, HZ, RA, SN, BR, SN, BR, SN]
# 1999  [SN, SN, HZ, SN, BR, HZ, SN, BR, HZ, SN, BR, H...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [SN, BR, SN, BR, HZ, HZ, SN, BR, SN, SN, HZ, S...
# 2005  [BR, HZ, BR, HZ, BR, UP, HZ, BR, HZ, BR, HZ, U...
# 2006  [SN, HZ, SN, BR, UP, HZ, BR, UP, HZ, SN, SN, S...
# 2007  [RA, BR, FZFG, BR, RA, FG, DZ, RA, RA, SN, BR,...
# 2008  [SN, SN, UP, HZ, SN, SN, BR, HZ, RA, SN, BR, H...
# 2009  [RA, BR, SN, HZ, RA, BR, BR, HZ, RA, SN, BR, H...
# 2010  [BR, HZ, SN, BR, HZ, BR, HZ, HZ, SN, SN, RA, R...
# 2011  [SN, BR, RA, SN, BR, RA, SN, BR, RA, SN, UP, S...
# 2012  [RA, BR, RA, SN, UP, HZ, RA, HZ, BR, RA, RA, H...
# 2013  [RA, RA, RA, SN, BR, RA, BR, RA, SN, HZ, RA, S...
# 2014  [UP, SN, BR, SN, BR, HZ, FZRA, SN, FZFG, BR, U...
# 2015  [SN, BR, RA, HZ, RA, SN, RA, RA, RA, RA, HZ, R...
# 2016  [RA, UP, RA, UP, SN, HZ, FZFG, BR, HZ, RA, FG,...
# 2017  [FZFG, BR, UP, HZ, FG, FZFG, BR, HZ, FG, HZ, U...
# 2018  [RA, RA, SN, BR, RA, BR, RA, SN, BR, UP, HZ, S...
# 2019  [SN, BR, SN, BR, SN, BR, UP, RA, SN, HZ, BR, S...
# 2020  [HZ, SN, HZ, SN, SN, FZFG, BR, HZ, FG, SN, BR,...
# 2021  [SN, SN, HZ, SN, SN, SN, FG, BR, FZFG, BR, HZ,...
# 2022                                                 []
#
#                                                       3  \
# 1996                           [SN, SN, SN, SN, SN, RA]
# 1997                                       [SN, SN, SN]
# 1998           [SN, SN, BR, SN, BR, SN, BR, SN, SN, SN]
# 1999  [SN, BR, SN, BR, SN, BR, HZ, HZ, SN, SN, SN, H...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [SN, BR, HZ, SN, BR, SN, FG, BR, HZ, SN, FG, B...
# 2005  [SN, BR, UP, SN, UP, SN, UP, UP, UP, RA, UP, U...
# 2006  [SN, BR, UP, SN, UP, UP, SN, UP, UP, SN, BR, U...
# 2007  [BR, HZ, SN, BR, HZ, RA, SN, PL, SN, BR, RA, D...
# 2008  [SN, RA, RA, BR, RA, RA, RA, RA, RA, RA, RA, B...
# 2009  [SN, BR, HZ, RA, RA, SN, RA, BR, SN, BR, SN, F...
# 2010  [RA, RA, RA, RA, RA, SN, RA, SN, HZ, RA, SN, R...
# 2011  [UP, SN, BR, SN, RA, HZ, RA, RA, BR, RA, UP, R...
# 2012  [RA, BR, SN, HZ, RA, SN, BR, UP, HZ, SN, BR, H...
# 2013  [SN, BR, RA, HZ, RA, BR, RA, SN, FZFG, BR, FG,...
# 2014  [UP, SN, BR, HZ, SN, BR, HZ, SN, UP, UP, RA, U...
# 2015  [SN, BR, RA, SN, BR, SN, BR, UP, SN, BR, UP, H...
# 2016  [RA, SN, SN, SN, BR, HZ, HZ, UP, SN, HZ, RA, R...
# 2017  [RA, RA, SN, SN, BR, UP, HZ, SN, BR, HZ, SN, B...
# 2018  [HZ, SN, BR, UP, SN, FZFG, BR, FG, SN, BR, UP,...
# 2019  [SN, BR, SN, BR, SN, BR, HZ, SN, BR, RA, SN, B...
# 2020  [SN, SN, HZ, SN, HZ, HZ, HZ, SN, HZ, SN, HZ, S...
# 2021  [SN, SN, SN, SN, HZ, SN, BR, HZ, SN, BR, SN, H...
# 2022                                                 []
#
#                                                       4  \
# 1996                                       [SN, SN, RA]
# 1997                                   [SN, SN, SN, RA]
# 1998               [SN, BR, RA, RA, SN, BR, SN, BR, SN]
# 1999           [SN, BR, SN, BR, SN, FG, SN, RA, SN, BR]
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004                       [SN, SN, SN, BR, RA, RA, RA]
# 2005  [SN, UP, SN, BR, UP, SN, BR, UP, SN, BR, UP, U...
# 2006  [SN, SN, BR, SN, SN, BR, UP, SN, BR, SN, FZFG,...
# 2007  [SN, RA, RA, RA, BR, RA, BR, RA, UP, RA, SN, B...
# 2008  [RA, SN, RA, SN, SN, FZFG, BR, UP, RA, FG, SN,...
# 2009  [SN, UP, UP, UP, RA, RA, RA, BR, BR, RA, RA, R...
# 2010  [RA, SN, RA, RA, RA, RA, SN, SN, RA, RA, RA, R...
# 2011  [RA, RA, SN, FZFG, BR, FG, RA, SN, SN, BR, SN,...
# 2012  [SN, HZ, RA, RA, UP, RA, UP, BR, BR, RA, RA, R...
# 2013  [SN, BR, RA, SN, SN, BR, HZ, SN, BR, HZ, RA, S...
# 2014  [RA, RA, RA, RA, SN, BR, HZ, RA, SN, BR, RA, R...
# 2015  [SN, HZ, RA, SN, RA, SN, BR, HZ, UP, SN, SN, B...
# 2016  [SN, BR, SN, BR, UP, RA, RA, RA, RA, SN, BR, H...
# 2017  [RA, RA, HZ, RA, RA, SN, BR, RA, SN, BR, UP, H...
# 2018  [SN, BR, SN, RA, RA, RA, RA, RA, RA, RA, RA, R...
# 2019  [RA, RA, RA, RA, RA, RA, BR, HZ, RA, RA, SN, B...
# 2020  [SN, BR, HZ, RA, SN, FG, BR, UP, RA, SN, UP, H...
# 2021  [SN, UP, HZ, SN, BR, SN, FZFG, BR, FG, RA, SN,...
# 2022                                                 []
#
#                                                       5  \
# 1996                                   [RA, FG, RA, RA]
# 1997                           [RA, RA, RA, RA, RA, RA]
# 1998  [RA, SN, BR, SN, BR, RA, RA, RA, RA, BR, RA, R...
# 1999  [SN, BR, RA, RA, RA, FG, BR, RA, RA, RA, FG, B...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [RA, BR, RA, BR, RA, SN, BR, RA, BR, RA, BR, R...
# 2005                       [RA, HZ, RA, BR, HZ, BR, BR]
# 2006           [RA, RA, RA, RA, BR, RA, RA, FG, BR, RA]
# 2007  [RA, RA, RA, RA, UP, BR, RA, RA, RA, RA, RA, R...
# 2008  [RA, RA, RA, RA, BR, FG, BR, RA, RA, RA, RA, R...
# 2009  [RA, RA, RA, RA, RA, RA, RA, RA, RA, BR, RA, R...
# 2010  [RA, BR, SN, BR, RA, FZFG, BR, FG, RA, RA, RA,...
# 2011  [RA, RA, RA, RA, BR, RA, RA, BR, RA, RA, RA, R...
# 2012  [SN, FZFG, HZ, FG, RA, RA, RA, RA, RA, BR, RA,...
# 2013  [SN, BR, HZ, RA, SN, RA, BR, SN, FZFG, BR, UP,...
# 2014  [RA, RA, RA, RA, HZ, BR, RA, RA, RA, RA, RA, R...
# 2015                           [RA, BR, BR, RA, RA, RA]
# 2016  [RA, RA, BR, RA, RA, RA, RA, RA, BR, RA, RA, R...
# 2017  [RA, RA, RA, RA, RA, RA, RA, RA, RA, BR, RA, R...
# 2018  [RA, SN, BR, UP, SN, BR, RA, RA, RA, BR, RA, S...
# 2019  [RA, SN, BR, RA, RA, RA, RA, RA, RA, RA, RA, F...
# 2020                                   [RA, RA, RA, RA]
# 2021               [RA, RA, RA, RA, RA, RA, RA, RA, RA]
# 2022                                                 []
#
#                                                       6  \
# 1996                                           [RA, SN]
# 1997                                               [RA]
# 1998  [RA, RA, RA, RA, RA, RA, RA, FG, BR, RA, FG, B...
# 1999  [RA, BR, RA, RA, RA, RA, RA, BR, RA, BR, RA, F...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [RA, RA, BR, FG, BR, RA, BR, RA, RA, RA, FG, B...
# 2005  [HZ, BR, FG, BR, HZ, BR, HZ, BR, BR, BR, HZ, H...
# 2006  [RA, RA, BR, HZ, HZ, HZ, HZ, HZ, RA, RA, BR, R...
# 2007  [RA, RA, RA, RA, RA, RA, RA, RA, RA, FG, BR, R...
# 2008  [RA, RA, BR, RA, BR, RA, RA, RA, RA, RA, BR, R...
# 2009  [RA, RA, HZ, RA, BR, RA, RA, BR, BR, FG, HZ, R...
# 2010  [HZ, RA, BR, RA, BR, HZ, RA, BR, RA, RA, BR, H...
# 2011  [BR, RA, BR, RA, RA, RA, RA, RA, RA, BR, RA, B...
# 2012  [RA, BR, RA, BR, RA, BR, RA, RA, FG, BR, RA, B...
# 2013  [RA, RA, RA, RA, RA, RA, RA, RA, RA, RA, HZ, R...
# 2014  [RA, BR, FG, BR, BR, RA, RA, BR, RA, RA, BR, R...
# 2015  [RA, RA, RA, RA, RA, RA, BR, RA, RA, RA, RA, R...
# 2016  [RA, RA, RA, BR, RA, RA, BR, RA, BR, RA, RA, B...
# 2017  [RA, RA, RA, RA, RA, RA, RA, RA, RA, BR, RA, B...
# 2018  [RA, RA, RA, RA, RA, FG, BR, FG, BR, RA, RA, H...
# 2019  [RA, BR, RA, FG, BR, RA, FG, BR, RA, BR, RA, F...
# 2020  [RA, BR, BR, RA, RA, RA, HZ, RA, BR, RA, RA, R...
# 2021  [RA, RA, RA, RA, RA, RA, RA, RA, RA, HZ, RA, H...
# 2022                                                 []
#
#                                                       7  \
# 1996                                           [RA, RA]
# 1997                                       [RA, RA, RA]
# 1998  [RA, RA, RA, BR, RA, RA, BR, RA, RA, RA, BR, R...
# 1999  [HZ, HZ, RA, HZ, RA, RA, RA, RA, BR, RA, BR, R...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [FG, BR, HZ, BR, HZ, RA, BR, HZ, RA, BR, HZ, R...
# 2005  [BR, HZ, BR, HZ, BR, BR, HZ, HZ, BR, HZ, HZ, B...
# 2006  [RA, RA, BR, RA, BR, BR, RA, RA, BR, RA, BR, R...
# 2007  [RA, RA, RA, RA, FG, BR, RA, BR, RA, RA, BR, R...
# 2008  [RA, BR, BR, RA, RA, HZ, RA, RA, BR, HZ, BR, R...
# 2009  [RA, HZ, BR, HZ, BR, HZ, RA, BR, HZ, RA, BR, H...
# 2010  [RA, RA, RA, BR, HZ, RA, RA, BR, RA, RA, RA, R...
# 2011  [RA, BR, RA, RA, FG, BR, RA, BR, RA, RA, BR, R...
# 2012  [RA, BR, RA, RA, BR, FG, BR, RA, RA, RA, FG, B...
# 2013  [BR, HZ, HZ, BR, HZ, RA, BR, BR, HZ, RA, HZ, R...
# 2014  [RA, BR, RA, FG, BR, RA, BR, RA, BR, RA, RA, R...
# 2015  [RA, HZ, RA, BR, HZ, BR, HZ, RA, HZ, HZ, RA, H...
# 2016  [RA, BR, RA, BR, RA, BR, RA, RA, RA, RA, RA, B...
# 2017  [RA, BR, RA, BR, RA, BR, RA, RA, BR, RA, RA, R...
# 2018  [RA, RA, RA, RA, BR, BR, RA, RA, BR, RA, RA, R...
# 2019  [RA, BR, BR, HZ, BR, HZ, BR, HZ, BR, HZ, BR, H...
# 2020  [BR, RA, RA, RA, FG, BR, RA, BR, RA, BR, RA, B...
# 2021  [HZ, RA, RA, HZ, RA, BR, HZ, RA, RA, RA, RA, H...
# 2022                                                 []
#
#                                                       8  \
# 1996                                                 []
# 1997  [RA, RA, RA, RA, RA, RA, RA, RA, RA, RA, RA, R...
# 1998  [RA, RA, BR, RA, RA, RA, BR, RA, BR, RA, BR, R...
# 1999  [RA, RA, BR, RA, RA, BR, FG, BR, RA, RA, BR, R...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [RA, BR, HZ, BR, HZ, BR, HZ, BR, HZ, BR, HZ, F...
# 2005  [RA, RA, BR, BR, HZ, RA, BR, HZ, RA, BR, BR, H...
# 2006  [RA, RA, BR, RA, RA, BR, RA, BR, RA, RA, BR, R...
# 2007  [RA, RA, RA, RA, BR, RA, BR, RA, BR, RA, RA, B...
# 2008  [RA, BR, RA, FG, BR, BR, HZ, RA, RA, BR, RA, B...
# 2009  [BR, HZ, BR, HZ, HZ, HZ, RA, BR, HZ, RA, FG, B...
# 2010  [RA, RA, HZ, RA, RA, BR, RA, RA, RA, FG, RA, R...
# 2011  [RA, RA, RA, RA, BR, RA, HZ, RA, BR, RA, BR, R...
# 2012  [RA, RA, RA, BR, RA, FG, BR, RA, BR, RA, BR, B...
# 2013  [BR, BR, RA, HZ, BR, FG, BR, RA, FG, RA, RA, F...
# 2014  [RA, BR, RA, BR, RA, BR, RA, FG, BR, RA, RA, R...
# 2015  [RA, BR, FG, BR, RA, HZ, RA, BR, RA, RA, BR, F...
# 2016  [RA, RA, BR, RA, BR, RA, RA, RA, RA, BR, RA, R...
# 2017  [RA, BR, RA, RA, BR, RA, RA, BR, RA, BR, RA, F...
# 2018  [RA, RA, RA, RA, BR, RA, BR, BR, FG, BR, RA, R...
# 2019  [RA, FG, BR, RA, BR, RA, BR, RA, BR, FG, RA, B...
# 2020  [RA, BR, RA, BR, RA, BR, RA, FG, BR, RA, RA, F...
# 2021  [RA, BR, RA, BR, RA, BR, RA, BR, RA, BR, RA, R...
# 2022                                                 []
#
#                                                       9  \
# 1996                                   [SN, RA, SN, SN]
# 1997                                                 []
# 1998  [RA, RA, RA, BR, FG, BR, RA, RA, BR, FG, BR, B...
# 1999  [RA, RA, BR, FG, BR, RA, BR, RA, RA, BR, RA, R...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [RA, BR, HZ, RA, BR, BR, BR, HZ, BR, HZ, FG, B...
# 2005  [RA, UP, RA, FZFG, BR, UP, FG, RA, RA, RA, RA,...
# 2006  [RA, BR, RA, FG, BR, RA, RA, RA, RA, BR, RA, R...
# 2007  [FG, BR, RA, FG, BR, FG, BR, RA, RA, SN, RA, B...
# 2008  [RA, RA, DZ, BR, RA, RA, BR, RA, RA, BR, RA, B...
# 2009  [RA, RA, HZ, RA, RA, RA, RA, RA, RA, RA, RA, B...
# 2010  [RA, BR, RA, BR, RA, RA, BR, RA, BR, RA, RA, B...
# 2011  [RA, BR, RA, BR, RA, BR, RA, BR, RA, BR, RA, B...
# 2012  [RA, BR, FG, BR, RA, RA, BR, RA, BR, RA, BR, R...
# 2013  [RA, RA, FG, BR, RA, FG, BR, RA, BR, RA, BR, R...
# 2014  [RA, BR, RA, BR, BR, RA, BR, FG, RA, RA, BR, R...
# 2015  [RA, RA, RA, RA, RA, RA, BR, RA, RA, BR, RA, F...
# 2016  [FG, BR, HZ, HZ, BR, RA, BR, RA, BR, RA, BR, B...
# 2017  [RA, BR, BR, RA, BR, RA, RA, BR, RA, RA, HZ, R...
# 2018  [RA, RA, BR, BR, RA, BR, RA, RA, BR, FG, BR, F...
# 2019  [RA, RA, FG, RA, FG, RA, FG, BR, RA, FG, BR, R...
# 2020  [RA, BR, RA, BR, RA, RA, RA, RA, RA, RA, BR, R...
# 2021  [RA, BR, FG, BR, RA, BR, RA, FG, BR, RA, SN, U...
# 2022                                                 []
#
#                                                      10  \
# 1996               [RA, SN, SN, SN, SN, SN, SN, SN, SN]
# 1997                                                 []
# 1998  [SN, BR, SN, BR, SN, BR, FG, BR, SN, SN, BR, S...
# 1999  [TS, FZRA, SN, BR, SN, BR, SN, BR, SN, BR, FG,...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [SN, SN, SN, SN, BR, SN, BR, BR, SN, BR, SN, F...
# 2005  [BR, SN, HZ, RA, SN, UP, RA, UP, SN, UP, SN, S...
# 2006  [BR, BR, RA, RA, SN, BR, UP, RA, BR, UP, RA, R...
# 2007  [RA, RA, RA, SN, RA, SN, BR, RA, SN, RA, SN, R...
# 2008  [FZFG, BR, RA, FG, SN, BR, RA, SN, BR, SN, RA,...
# 2009  [SN, BR, RA, BR, RA, BR, RA, BR, RA, RA, RA, R...
# 2010  [RA, RA, BR, RA, RA, SN, BR, RA, SN, BR, RA, R...
# 2011  [FZFG, BR, UP, FG, RA, UP, RA, RA, UP, BR, RA,...
# 2012  [RA, RA, RA, BR, RA, BR, RA, BR, BR, RA, RA, S...
# 2013  [SN, BR, RA, RA, RA, BR, RA, SN, BR, RA, BR, R...
# 2014  [RA, RA, RA, SN, BR, UP, SN, BR, RA, SN, FZFG,...
# 2015  [RA, SN, RA, BR, RA, BR, BR, FG, FZFG, BR, RA,...
# 2016         [HZ, RA, SN, FZFG, BR, FG, SN, RA, RA, BR]
# 2017  [BR, BR, RA, RA, RA, BR, RA, BR, RA, BR, RA, R...
# 2018  [RA, UP, RA, BR, RA, HZ, RA, BR, RA, BR, RA, R...
# 2019  [RA, RA, SN, BR, RA, FG, BR, RA, FG, BR, SN, B...
# 2020  [RA, FG, BR, UP, HZ, FG, BR, SN, SN, SN, SN, F...
# 2021  [SN, FZFG, BR, UP, FG, SN, FG, FZFG, BR, SN, B...
# 2022                                                 []
#
#                                                      11  \
# 1996                       [SN, SN, SN, SN, SN, SN, SN]
# 1997                                                 []
# 1998  [BR, SN, SN, SN, HZ, SN, BR, SN, BR, SN, BR, S...
# 1999  [SN, BR, HZ, SN, BR, SN, BR, SN, BR, SN, BR, S...
# 2000                                                 []
# 2001                                                 []
# 2002                                                 []
# 2003                                                 []
# 2004  [SN, BR, SN, BR, SN, BR, SN, BR, SN, BR, SN, B...
# 2005  [SN, FZFG, BR, UP, HZ, FG, SN, FZFG, BR, FG, U...
# 2006  [SN, FZFG, BR, FG, SN, BR, FZFG, BR, FG, SN, S...
# 2007  [RA, SN, BR, RA, SN, BR, RA, SN, HZ, RA, RA, B...
# 2008  [SN, HZ, RA, SN, RA, SN, BR, RA, SN, BR, RA, S...
# 2009  [RA, RA, RA, BR, RA, SN, UP, RA, RA, RA, SN, H...
# 2010  [RA, RA, RA, SN, BR, RA, BR, RA, BR, RA, SN, B...
# 2011  [UP, RA, FZRA, UP, RA, SN, FZFG, BR, UP, RA, F...
# 2012  [SN, RA, SN, UP, HZ, SN, UP, RA, BR, RA, RA, S...
# 2013  [SN, BR, BR, RA, SN, BR, RA, BR, HZ, RA, FZRA,...
# 2014  [RA, HZ, RA, HZ, RA, RA, RA, RA, RA, SN, SN, B...
# 2015  [SN, BR, SN, BR, UP, RA, SN, BR, RA, SN, BR, R...
# 2016  [RA, RA, RA, SN, BR, HZ, SN, BR, RA, RA, SN, B...
# 2017  [SN, FZFG, BR, FG, SN, BR, SN, BR, SN, BR, SN,...
# 2018  [RA, RA, RA, UP, RA, RA, RA, RA, SN, BR, SN, B...
# 2019  [SN, BR, BR, SN, BR, HZ, BR, HZ, SN, BR, SN, B...
# 2020  [HZ, HZ, SN, SN, SN, BR, SN, BR, SN, FZFG, BR,...
# 2021  [SN, BR, SN, BR, SN, BR, FZFG, BR, HZ, FG, BR,...
# 2022                                                 []
#
#                                                      12 class_month
# 1996                               [SN, SN, SN, SN, SN]          05
# 1997                                                 []          04
# 1998  [SN, BR, SN, BR, SN, BR, SN, BR, SN, BR, SN, B...          04
# 1999       [SN, SN, SN, BR, SN, SN, SN, SN, SN, SN, SN]          04
# 2000                                                 []          05
# 2001                                                 []          05
# 2002                                                 []          05
# 2003                                                 []          04
# 2004  [SN, BR, SN, BR, SN, BR, SN, BR, HZ, SN, SN, S...          04
# 2005  [SN, BR, HZ, BR, HZ, SN, SN, BR, UP, UP, UP, S...          04
# 2006  [SN, FZFG, BR, FG, SN, RA, BR, SN, RA, SN, UP,...          05
# 2007  [SN, SN, SN, SN, SN, SN, SN, BR, SN, BR, SN, B...          04
# 2008  [SN, HZ, SN, BR, SN, BR, RA, RA, BR, SN, BR, S...          05
# 2009  [FZFG, BR, FG, SN, BR, RA, SN, FZFG, BR, FG, R...          05
# 2010  [RA, SN, RA, SN, BR, RA, RA, RA, RA, SN, BR, U...          04
# 2011  [SN, BR, UP, RA, SN, BR, UP, RA, UP, RA, SN, B...          05
# 2012  [RA, RA, RA, RA, SN, UP, BR, RA, SN, RA, SN, S...          04
# 2013  [FZRA, UP, FZRA, UP, BR, UP, SN, FZRA, SN, FZF...          05
# 2014  [SN, UP, SN, FZFG, BR, RA, FG, SN, BR, FZFG, B...          04
# 2015  [RA, RA, SN, HZ, RA, RA, HZ, RA, SN, SN, RA, R...          04
# 2016  [SN, BR, RA, SN, HZ, SN, UP, HZ, SN, SN, BR, H...          04
# 2017  [UP, BR, SN, BR, SN, BR, RA, RA, SN, FZFG, BR,...          05
# 2018  [SN, FZFG, BR, FG, SN, FZFG, BR, FG, BR, RA, S...          05
# 2019  [SN, BR, SN, BR, SN, FZFG, BR, HZ, FG, SN, UP,...          04
# 2020  [SN, BR, HZ, SN, FZFG, BR, HZ, FG, SN, UP, SN,...          04
# 2021  [SN, UP, HZ, SN, UP, HZ, SN, UP, SN, HZ, SN, S...           ?
# 2022                                                 []           ?

# %%
# finally: csv file to import into classifier 
weather_types.to_csv('csv/multinomial_features.csv', index=True)
# pickle data turned out to be better to preserve the data types 
x = weather_types.transpose().to_dict()
with open('multinomial_dict.pkl', 'wb') as f:
    pickle.dump(x, f)

# %%
# get all weather types that exist in the data set 
existing_weather_types = set()
for i, x in zip(weather_types.index, weather_types.values): 
    for y in x[:-1]: 
        for z in y: 
            existing_weather_types.add(z)
print(existing_weather_types)
# Out:
# {'DZ', 'UP', 'SN', 'DU', 'HZ', 'RA', 'PL', 'BLSN', 'FZFG', 'FZRA', 'TS', 'BR', 'FG'}
